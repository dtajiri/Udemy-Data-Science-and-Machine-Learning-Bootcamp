# %% [markdown]
# # Notebook Imports

# %%
from os import walk
from os.path import join

import pandas as pd
import matplotlib.pylab as plt
import numpy as np

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from bs4 import BeautifulSoup
from wordcloud import WordCloud
from PIL import Image

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # Constants

# %%
EXAMPLE_FILE = 'SpamData/01_Processing/practice_email.txt'
SPAM_1_PATH = 'SpamData/01_Processing/spam_assassin_corpus/spam_1'
SPAM_2_PATH = 'SpamData/01_Processing/spam_assassin_corpus/spam_2'
EASY_NONSPAM_1_PATH = 'SpamData/01_Processing/spam_assassin_corpus/easy_ham_1'
EASY_NONSPAM_2_PATH = 'SpamData/01_Processing/spam_assassin_corpus/easy_ham_2'

SPAM_CAT = 1
HAM_CAT = 0
VOCAB_SIZE = 2500

DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'
WORD_ID_FILE = 'SpamData/01_Processing/word-by-id.csv'

TRAINING_DATA_FILE = 'SpamData/02_Training/train-data.txt'
TEST_DATA_FILE = 'SpamData/02_Training/test-data.txt'

WHALE_FILE = 'SpamData/01_Processing/wordcloud_resources/whale-icon.png'
SKULL_FILE = 'SpamData/01_Processing/wordcloud_resources/skull-icon.png'
THUMBS_UP_FILE = 'SpamData/01_Processing/wordcloud_resources/thumbs-up.png'
THUMBS_DOWN_FILE = 'SpamData/01_Processing/wordcloud_resources/thumbs-down.png'
FONT_FILE = 'SpamData/01_Processing/wordcloud_resources/OpenSansCondensed-Light.ttf'

# %% [markdown]
# # Reading Files

# %%
stream = open(EXAMPLE_FILE, encoding='latin-1')
message = stream.read()
stream.close()

print(type(message))
print(message)
# Out:
# <class 'str'>
# From exmh-workers-admin@redhat.com  Thu Aug 22 12:36:23 2002
# Return-Path: <exmh-workers-admin@spamassassin.taint.org>
# Delivered-To: zzzz@localhost.netnoteinc.com
# Received: from localhost (localhost [127.0.0.1])
# 	by phobos.labs.netnoteinc.com (Postfix) with ESMTP id D03E543C36
# 	for <zzzz@localhost>; Thu, 22 Aug 2002 07:36:16 -0400 (EDT)
# Received: from phobos [127.0.0.1]
# 	by localhost with IMAP (fetchmail-5.9.0)
# 	for zzzz@localhost (single-drop); Thu, 22 Aug 2002 12:36:16 +0100 (IST)
# Received: from listman.spamassassin.taint.org (listman.spamassassin.taint.org [66.187.233.211]) by
#     dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g7MBYrZ04811 for
#     <zzzz-exmh@spamassassin.taint.org>; Thu, 22 Aug 2002 12:34:53 +0100
# Received: from listman.spamassassin.taint.org (localhost.localdomain [127.0.0.1]) by
#     listman.redhat.com (Postfix) with ESMTP id 8386540858; Thu, 22 Aug 2002
#     07:35:02 -0400 (EDT)
# ...

# %%
import sys
sys.getfilesystemencoding()
# Out:
# 'utf-8'

# %%
stream = open(EXAMPLE_FILE, encoding='latin-1')
is_body = False
lines = []
for line in stream:
    if is_body:
        lines.append(line)
    elif line == '\n':
        is_body = True

stream.close()

email_body = '\n'.join(lines)
print(email_body)
# Out:
# Dear Mr Still
#
#
#
# Good tidings to you and all your staff for the festive season ahead (Christmas).
#
# Now to the crux of the matter-in-hand: I am a fully qualified Santa Claus and am wondering whether you might consider me to run my own "Santa's Grotto" in your store.
#
# But WAIT! You're probably thinking: "What makes him so special?"
#
# Well, first of all, I have made several changes to the characterisation of Father Christmas. Rather than greeting the children with shouts of "Ho, ho, ho!" I prefer to whisper the phrase "Dependence is not unfathomable in this cruel world we live in". In addition, my gifts are ALL hand-made, ranging from felt hoops to vanilla-pod holders.
#
# You will note also, from the enclosed sketch, that I have radically redesigned Santa's outfit and have renamed my character "Lord Buckles". Would you be interested in employing me? I promise NEVER to let you down.
#
# I look forward to hearing from you.
#
#
#
# Best wishes
#
# Robin Cooper
#
# ...

# %% [markdown]
# # Generator Functions

# %%
def generate_squares(N):
    for my_number in range(N):
        yield my_number ** 2

# %%
for i in generate_squares(5):
    print(i, end = '->')
# Out:
# 0->1->4->9->16->

# %% [markdown]
# # Email Body Extraction

# %%
def email_body_generator(path):
    
    for root, dirnames, filenames in walk(path): # walk function generates the files names in a directory by 
                                                # walking the tree from the top to the bottom and yeild a tuple
        
        for file_name in filenames:
            
            filepath = join(root,file_name)
            
            stream = open(filepath, encoding='latin-1')
            
            is_body = False
            lines = []
            
            for line in stream:
                if is_body:
                    lines.append(line)
                elif line == '\n':
                    is_body = True

            stream.close()

            email_body = '\n'.join(lines)

            yield file_name, email_body

# %%
def df_from_directory(path, classification):
    rows = []
    row_names = []
    
    for file_name, email_body in email_body_generator(path):
        rows.append({'CATEGORY': classification, 'MESSAGE': email_body})
        row_names.append(file_name)
        
    return pd.DataFrame(rows, index = row_names)

# %%
spam_emails = df_from_directory(SPAM_1_PATH, SPAM_CAT)
spam_emails = spam_emails.append(df_from_directory(SPAM_2_PATH, SPAM_CAT))
spam_emails
# Out:
#                                         CATEGORY  \
# 00249.5f45607c1bffe89f60ba1ec9f878039a         1
# 00373.ebe8670ac56b04125c25100a36ab0510         1
# 00214.1367039e50dc6b7adb0f2aa8aba83216         1
# 00210.050ffd105bd4e006771ee63cabc59978         1
# 00033.9babb58d9298daa2963d4f514193d7d6         1
# ...                                          ...
# 01311.43bfe86df65d53c5f7ca2365dc12582b         1
# 00851.dc5452f80ba0bb8481dfc48f70380c4d         1
# 01328.b23902de23cb3ca1f3334517282372b2         1
# 01244.9ef966101737a6fc27d8965def288d70         1
# 00788.b98a23c07d59156d172683fc29b80661         1
#
#                                                                                   MESSAGE
# 00249.5f45607c1bffe89f60ba1ec9f878039a  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 00373.ebe8670ac56b04125c25100a36ab0510  ATTENTION: This is a MUST for ALL Computer Use...
# 00214.1367039e50dc6b7adb0f2aa8aba83216  This is a multi-part message in MIME format.\n...
# ...

# %%
ham_emails = df_from_directory(EASY_NONSPAM_1_PATH, HAM_CAT)
ham_emails = ham_emails.append(df_from_directory(EASY_NONSPAM_2_PATH, HAM_CAT))
ham_emails
# Out:
#                                         CATEGORY  \
# 00769.25bf9a767b5db0ed93f03c1637281663         0
# 01074.8590d61ac0aeeadb58dc2f2ba776c406         0
# 02479.14365bcad3a60fcf24c5c1813f6291fb         0
# 01417.ce7b07a2114218dbac682b599785820d         0
# 00357.d559b71616f64ba1d1c1e61a03644fd4         0
# ...                                          ...
# 00609.dd49926ce94a1ea328cce9b62825bc97         0
# 00957.e0b56b117f3ec5f85e432a9d2a47801f         0
# 01127.841233b48eceb74a825417d8d918abf8         0
# 01178.5c977dff972cd6eef64d4173b90307f0         0
# 00747.352d424267d36975a7b40b85ffd0885e         0
#
#                                                                                   MESSAGE
# 00769.25bf9a767b5db0ed93f03c1637281663  \n\nIn a message dated 9/24/2002 11:24:58 AM, ...
# 01074.8590d61ac0aeeadb58dc2f2ba776c406  Hiya, I always seem to get errors when I do an...
# 02479.14365bcad3a60fcf24c5c1813f6291fb  \n\nI don't know how one can expect better and...
# ...

# %%
data = spam_emails.append(ham_emails)
data
# Out:
#                                         CATEGORY  \
# 00249.5f45607c1bffe89f60ba1ec9f878039a         1
# 00373.ebe8670ac56b04125c25100a36ab0510         1
# 00214.1367039e50dc6b7adb0f2aa8aba83216         1
# 00210.050ffd105bd4e006771ee63cabc59978         1
# 00033.9babb58d9298daa2963d4f514193d7d6         1
# ...                                          ...
# 00609.dd49926ce94a1ea328cce9b62825bc97         0
# 00957.e0b56b117f3ec5f85e432a9d2a47801f         0
# 01127.841233b48eceb74a825417d8d918abf8         0
# 01178.5c977dff972cd6eef64d4173b90307f0         0
# 00747.352d424267d36975a7b40b85ffd0885e         0
#
#                                                                                   MESSAGE
# 00249.5f45607c1bffe89f60ba1ec9f878039a  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 00373.ebe8670ac56b04125c25100a36ab0510  ATTENTION: This is a MUST for ALL Computer Use...
# 00214.1367039e50dc6b7adb0f2aa8aba83216  This is a multi-part message in MIME format.\n...
# ...

# %% [markdown]
# # Data Cleaning: Checking for Missing Values

# %%
# check if any message bodies are null
data.MESSAGE.isnull().values.any()
# Out:
# False

# %%
empty_string = ""
len(empty_string)
# Out:
# 0

# %%
# check if there are empty emails (string length zero)
(data.MESSAGE.str.len() == 0).any()
# Out:
# True

# %%
(data.MESSAGE.str.len() == 0).sum()
# Out:
# 4

# %%
# Challenge: how would you check the number of entries with null/None values?
data.MESSAGE.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Locate empty emails

# %%
type(data.MESSAGE.str.len() == 0)
# Out:
# pandas.core.series.Series

# %%
data[data.MESSAGE.str.len() == 0].index
# Out:
# Index(['cmds', 'cmds', '.DS_Store', 'cmds'], dtype='object')

# %% [markdown]
# # Remove System File Entries from Dataframe

# %%
data.drop(['cmds'], inplace = True)
data
# Out:
#                                         CATEGORY  \
# 00249.5f45607c1bffe89f60ba1ec9f878039a         1
# 00373.ebe8670ac56b04125c25100a36ab0510         1
# 00214.1367039e50dc6b7adb0f2aa8aba83216         1
# 00210.050ffd105bd4e006771ee63cabc59978         1
# 00033.9babb58d9298daa2963d4f514193d7d6         1
# ...                                          ...
# 00609.dd49926ce94a1ea328cce9b62825bc97         0
# 00957.e0b56b117f3ec5f85e432a9d2a47801f         0
# 01127.841233b48eceb74a825417d8d918abf8         0
# 01178.5c977dff972cd6eef64d4173b90307f0         0
# 00747.352d424267d36975a7b40b85ffd0885e         0
#
#                                                                                   MESSAGE
# 00249.5f45607c1bffe89f60ba1ec9f878039a  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 00373.ebe8670ac56b04125c25100a36ab0510  ATTENTION: This is a MUST for ALL Computer Use...
# 00214.1367039e50dc6b7adb0f2aa8aba83216  This is a multi-part message in MIME format.\n...
# ...

# %% [markdown]
# # Add Document IDs to Track Emails in Dataset

# %%
document_ids = range(0, len(data.index))
data['DOC_ID'] = document_ids
data['DOC_ID']
# Out:
# 00249.5f45607c1bffe89f60ba1ec9f878039a       0
# 00373.ebe8670ac56b04125c25100a36ab0510       1
# 00214.1367039e50dc6b7adb0f2aa8aba83216       2
# 00210.050ffd105bd4e006771ee63cabc59978       3
# 00033.9babb58d9298daa2963d4f514193d7d6       4
#                                           ...
# 00609.dd49926ce94a1ea328cce9b62825bc97    5791
# 00957.e0b56b117f3ec5f85e432a9d2a47801f    5792
# 01127.841233b48eceb74a825417d8d918abf8    5793
# 01178.5c977dff972cd6eef64d4173b90307f0    5794
# 00747.352d424267d36975a7b40b85ffd0885e    5795
# Name: DOC_ID, Length: 5796, dtype: int64

# %%
data['FILE_NAME'] = data.index
data.set_index('DOC_ID', inplace = True)
data
# Out:
#         CATEGORY                                            MESSAGE  \
# DOC_ID
# 0              1  Dear Homeowner,\n\n \n\nInterest Rates are at ...
# 1              1  ATTENTION: This is a MUST for ALL Computer Use...
# 2              1  This is a multi-part message in MIME format.\n...
# 3              1  IMPORTANT INFORMATION:\n\n\n\nThe new domain n...
# 4              1  This is the bottom line.  If you can GIVE AWAY...
# ...          ...                                                ...
# 5791           0  I'm one of the 30,000 but it's not working ver...
# 5792           0  Damien Morton quoted:\n\n>W3C approves HTML 4 ...
# 5793           0  On Mon, 2002-07-22 at 06:50, che wrote:\n\n\n\...
# 5794           0  Once upon a time, Manfred wrote :\n\n\n\n> I w...
# 5795           0  If you run Pick, and then use the "New FTOC" b...
#
#                                      FILE_NAME
# DOC_ID
# 0       00249.5f45607c1bffe89f60ba1ec9f878039a
# ...

# %% [markdown]
# # Save to File using Pandas

# %%
data.to_json(DATA_JSON_FILE)

# %% [markdown]
# # Number of Spam Messages Visualized (Pie Charts)

# %%
data.CATEGORY.value_counts()
# Out:
# 0    3900
# 1    1896
# Name: CATEGORY, dtype: int64

# %%
amount_of_spam = data.CATEGORY.value_counts()[1]
amount_of_ham = data.CATEGORY.value_counts()[0]

# %%
category_names = ['Spam', 'Legit Mail']
sizes = [amount_of_spam, amount_of_ham]

plt.figure(figsize=(2,2),dpi=227)
plt.pie(sizes, labels=category_names, textprops={'fontsize':8}, startangle = 90, autopct = '%1.1f%%',
       colors =['indianred','skyblue'], pctdistance=0.55) # explode=[0.05,0.05] to add separation between items

#draw circle
#center_circle = plt.Circle((0,0), radius=0.45, fc='white')
#plt.gca().add_artist(center_circle)
#plt.show()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fdb4852fe20>,
# ...
#  [Text(-0.9417151198007834, 0.5684827465619308, 'Spam'),
#   Text(0.9417151198007836, -0.5684827465619303, 'Legit Mail')],
#  [Text(-0.4708575599003917, 0.2842413732809654, '32.7%'),
#   Text(0.4708575599003918, -0.28424137328096516, '67.3%')])

# %%
#TEST

category_names = ['Spam', 'Legit Mail', 'Updates', 'Promotions']
sizes = [12, 20, 47, 39]

plt.figure(figsize=(2,2),dpi=227)
plt.pie(sizes, labels=category_names, textprops={'fontsize':5}, startangle = 0, autopct = '%1.f%%',
       colors =['indianred','skyblue','lightgreen','palegoldenrod'], pctdistance=0.75, explode = [0.05,0.05,0.05,0.05])

#draw circle
center_circle = plt.Circle((0,0), radius=0.6, fc='white')
plt.gca().add_artist(center_circle)
plt.show()

# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ### Text Pre-Processing

# %%
# convert to lower case
msg = 'All work an no play makes Jack a dull boy.'
msg.lower()
# Out:
# 'all work an no play makes jack a dull boy.'

# %% [markdown]
# ## Download the NLTK Resources (Tokenizer & Stopwords)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/danatajiri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danatajiri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Tokenizing
word_tokenize(msg.lower())
# Out:
# ['all', 'work', 'an', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', '.']

# %%
# Removing Stop Words
print(type(stopwords.words('english')))
stop_words = set(stopwords.words('english'))
type(stop_words)
# Out:
# <class 'list'>
# set

# %%
if 'this' in stop_words: print('Found it!')
if 'hello' not in stop_words: print('not found')
# Out:
# Found it!
# not found

# %% [markdown]
# ## Word Stems and Stemming

# %%
msg = 'All work an no play makes Jack a dull boy. To be or not to be. \
        Nobody expects the Spanish Inquisition!'
words = word_tokenize(msg.lower())

#stemmer = PorterStemmer() # quite a few stemmers to choose from other than PorterStemmer
stemmer = SnowballStemmer('english') # can use languages other than english (like arabic or french)
filtered_words = []

#Challenge: append non-stop words to filtered_words
for word in words: 
    if word not in stop_words:
        stemmed_word = stemmer.stem(word)
        filtered_words.append(stemmed_word)
        
print(filtered_words)
# Out:
# ['work', 'play', 'make', 'jack', 'dull', 'boy', '.', '.', 'nobodi', 'expect', 'spanish', 'inquisit', '!']

# %% [markdown]
# ## Removing Punctuation

# %%
print('p'.isalpha())
'?'.isalpha()
# Out:
# True
# False

# %%
msg = 'All work an no play makes Jack a dull boy. To be or not to be. \
        Nobody expects the Spanish Inquisition!'
words = word_tokenize(msg.lower())

#stemmer = PorterStemmer() # quite a few stemmers to choose from other than PorterStemmer
stemmer = SnowballStemmer('english') # can use languages other than english (like arabic or french)
filtered_words = []

#Challenge: append non-stop words and no punctuations to filtered_words
for word in words: 
    if word not in stop_words and word.isalpha() == True:
        stemmed_word = stemmer.stem(word)
        filtered_words.append(stemmed_word)
        
print(filtered_words)
# Out:
# ['work', 'play', 'make', 'jack', 'dull', 'boy', 'nobodi', 'expect', 'spanish', 'inquisit']

# %% [markdown]
# ## Removing HTML tags from Emails

# %%
soup = BeautifulSoup(data.at[2,'MESSAGE'], 'html.parser') #first parameter is the text that you'd like to parse
                                                        #second parameter is the parser you'd like to use
    
print(soup.prettify())
# Out:
# This is a multi-part message in MIME format.
#
#
#
# ------=_NextPart_000_1CDC19_01C25366.4B57F3A0
#
# Content-Type: text/plain;
#
# 	charset="Windows-1252"
#
# Content-Transfer-Encoding: quoted-printable
#
#
#
#  We dare you...
#
#  Try to find a better annuity!
#
# =20
#
#   - 5.40% Guaranteed for 6 Years=0A=
#
# - 6 Year Surrender Charge=0A=
#
# - 5% Agent
#
# Commission up to age 80=09
#
# Call today for more information!
#
#  800-888-7641 ext. 103
#
# - or -
#
#
#
# Please fill out the form below for more information	=20
#
# Name:	 	  =09
#
# E-mail:	 	=20
#
# Phone:	 	=20
#
# City:	 	 State:	 	=20
#
#  	    =09
#
# =20
#
#  PMG Financial Services
#
# *5.40% for deposits of $100,000 and up, 5.25% interest for deposits
#
# totalling $25,000-$99,999.	=20
#
# We don't want anyone to receive our mailings who does not wish to
#
# receive them. This is a professional communication sent to insurance
#
# professionals. To be removed from this mailing list, DO NOT REPLY to
#
# ...

# %%
soup.get_text()
# Out:
# 'This is a multi-part message in MIME format.\n\n\n\n------=_NextPart_000_1CDC19_01C25366.4B57F3A0\n\nContent-Type: text/plain;\n\n\tcharset="Windows-1252"\n\nContent-Transfer-Encoding: quoted-printable\n\n\n\n We dare you...\n\n Try to find a better annuity!\n\n=20\n\n  - 5.40% Guaranteed for 6 Years=0A=\n\n- 6 Year Surrender Charge=0A=\n\n- 5% Agent\n\nCommission up to age 80=09\n\nCall today for more information!\n\n 800-888-7641 ext. 103\n\n- or -\n\n\n\nPlease fill out the form below for more information\t=20\n\nName:\t \t  =09\n\nE-mail:\t \t=20\n\nPhone:\t \t=20\n\nCity:\t \t State:\t \t=20\n\n \t    =09\n\n=20\n\n PMG Financial Services\n\n*5.40% for deposits of $100,000 and up, 5.25% interest for deposits\n\ntotalling $25,000-$99,999.\t=20\n\nWe don\'t want anyone to receive our mailings who does not wish to\n\nreceive them. This is a professional communication sent to insurance\n\nprofessionals. To be removed from this mailing list, DO NOT REPLY to\n\nthis message. Instead,
# ...

# %% [markdown]
# ## Functions for Email Processing

# %%
# function for Tokenizing and Stemming and Removing Punctuations
def clean_message(message, stemmer = PorterStemmer(), stop_words = set(stopwords.words('english'))):
    
    # Converts to Lower Case and splits the words
    words = word_tokenize(message.lower())
    
    filtered_words = []
    
    for word in words:
        # Remove the stop words and punctuation
        if word not in stop_words and word.isalpha() == True:
            filtered_words.append(stemmer.stem(word))
       
    return filtered_words

# %%
clean_message(email_body)
# Out:
# ['dear',
#  'mr',
#  'still',
#  'good',
#  'tide',
#  'staff',
#  'festiv',
#  'season',
#  'ahead',
#  'christma',
#  'crux',
#  'fulli',
#  'qualifi',
#  'santa',
#  'clau',
#  'wonder',
#  'whether',
#  'might',
#  'consid',
#  'run',
#  'santa',
#  'grotto',
#  'store',
#  'wait',
#  'probabl',
#  'think',
#  'make',
#  'special',
#  'well',
#  'first',
#  'made',
#  'sever',
#  'chang',
#  'characteris',
#  'father',
#  'christma',
#  'rather',
#  'greet',
#  'children',
#  'shout',
#  'ho',
#  'ho',
#  'ho',
#  'prefer',
#  'whisper',
#  'phrase',
#  'depend',
#  'unfathom',
#  'cruel',
#  'world',
#  'live',
#  'addit',
#  'gift',
#  'rang',
#  'felt',
#  'hoop',
#  'holder',
#  'note',
#  'also',
#  'enclos',
#  'sketch',
#  'radic',
#  'redesign',
#  'santa',
#  'outfit',
#  'renam',
#  'charact',
#  'lord',
#  'buckl',
#  'would',
#  'interest',
#  'employ',
#  'promis',
#  'never',
#  'let',
#  'look',
#  'forward',
#  'hear',
#  'best',
#  'wish',
#  'robin',
# ...

# %%
# modified function to include removal of html tags
def clean_msg_no_html(message, stemmer = PorterStemmer(), stop_words = set(stopwords.words('english'))):
    
    # Remove HTML tags
    soup = BeautifulSoup(message, 'html.parser')
    cleaned_text = soup.get_text()
    
    
    # Converts to Lower Case and splits the words
    words = word_tokenize(cleaned_text.lower())
    
    filtered_words = []
    
    for word in words:
        # Remove the stop words and punctuation
        if word not in stop_words and word.isalpha() == True:
            filtered_words.append(stemmer.stem(word))
    
    
    return filtered_words

# %%
clean_msg_no_html(data.at[2, 'MESSAGE'])
# Out:
# ['messag',
#  'mime',
#  'format',
#  'dare',
#  'tri',
#  'find',
#  'better',
#  'annuiti',
#  'guarante',
#  'year',
#  'surrend',
#  'agent',
#  'commiss',
#  'age',
#  'call',
#  'today',
#  'inform',
#  'ext',
#  'pleas',
#  'fill',
#  'form',
#  'inform',
#  'name',
#  'phone',
#  'citi',
#  'state',
#  'pmg',
#  'financi',
#  'servic',
#  'deposit',
#  'interest',
#  'deposit',
#  'total',
#  'want',
#  'anyon',
#  'receiv',
#  'mail',
#  'wish',
#  'receiv',
#  'profession',
#  'commun',
#  'sent',
#  'insur',
#  'profession',
#  'remov',
#  'mail',
#  'list',
#  'repli',
#  'messag',
#  'instead',
#  'go',
#  'http',
#  'legal',
#  'notic',
#  'dare',
#  'find',
#  'better',
#  'annuiti',
#  'call',
#  'today',
#  'inform',
#  'pleas',
#  'fill',
#  'form',
#  'inform',
#  'name',
#  'phone',
#  'citi',
#  'state',
#  'deposit',
#  'interest',
#  'deposit',
#  'total',
#  'want',
#  'anyon',
#  'receiv',
#  'mail',
#  'wish',
#  'receiv',
#  'profession',
#  'sent',
# ...

# %% [markdown]
# # Apply Cleaning and Tokenization to all messages

# %% [markdown]
# ### Slicing Dataframes and Series & Creating Subsets

# %%
data.iat[2, 2]
# Out:
# '00214.1367039e50dc6b7adb0f2aa8aba83216'

# %%
data.iloc[5:11]
# Out:
#         CATEGORY                                            MESSAGE  \
# DOC_ID
# 5              1  ------=_NextPart_000_00B8_51E06B6A.C8586B31\n\...
# 6              1  <STYLE type="text/css">\n\n<!--\n\nP{\n\n  fon...
# 7              1  <HR>\n\n<html>\n\n<head>\n\n  <title>Secured I...
# 8              1  <table width="600" border="20" align="center" ...
# 9              1  <html>\n\n\n\n<head>\n\n<meta http-equiv="Cont...
# 10             1  Dear Consumers, Increase your Business Sales! ...
#
#                                      FILE_NAME
# DOC_ID
# 5       00187.efd97ab2034b3384606e21db00014ecb
# 6       00500.85b72f09f6778a085dc8b6821965a76f
# 7       00493.1c5f59825f7a246187c137614fb1ea82
# 8       00012.381e4f512915109ba1e0853a7a8407b2
# 9       00487.139a2f4e8edbbdd64441536308169d74
# 10      00159.b16f070a576c2eb1533aa9e2cf8e6b77

# %%
first_emails = data.MESSAGE.iloc[0:3]

nested_list = first_emails.apply(clean_message)

# %%
# flat_list = []
# for sublist in nested_list:
#     for item in sublist:
#         flat_list.append(item)

flat_list = [item for sublist in nested_list for item in sublist]
len(flat_list)
# Out:
# 390

# %%
# use apply() on all messages in the dataframe
nested_list = data.MESSAGE.apply(clean_msg_no_html)
# Out:
# /Users/danatajiri/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.post-gazette.com/columnists/20020905brian5
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
nested_list.tail()
# Out:
# DOC_ID
# 5791    [one, work, well, week, te, updat, server, syn...
# 5792    [damien, morton, quot, approv, html, abl, say,...
# 5793    [mon, che, wrote, that, correct, line, ad, rep...
# 5794    [upon, time, manfr, wrote, would, like, instal...
# 5795    [run, pick, use, new, ftoc, button, show, mess...
# Name: MESSAGE, dtype: object

# %% [markdown]
# ### Using logic to Slice Dataframes

# %%
data[data.CATEGORY == 1].tail()
# Out:
#         CATEGORY                                            MESSAGE  \
# DOC_ID
# 1891           1  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# 1892           1  <html>\n\n<HEAD> \n\n<TITLE>creditfix</TITLE> ...
# 1893           1  Hello:\n\n\n\nAre you satisfied with your ISP?...
# 1894           1  <html><HEAD><TITLE>creditfix</TITLE> \n\n</HEA...
# 1895           1  <HTML><HEAD></HEAD><BODY><b><FONT SIZE=3D4>In ...
#
#                                      FILE_NAME
# DOC_ID
# 1891    01311.43bfe86df65d53c5f7ca2365dc12582b
# 1892    00851.dc5452f80ba0bb8481dfc48f70380c4d
# 1893    01328.b23902de23cb3ca1f3334517282372b2
# 1894    01244.9ef966101737a6fc27d8965def288d70
# 1895    00788.b98a23c07d59156d172683fc29b80661

# %%
# Challenge: create two variables (doc_ids_spam, doc_ids_ham) which hold onto the indices
# for the spam and the non_spam emails respectively

doc_ids_spam = data[data.CATEGORY == 1].index
doc_ids_ham = data[data.CATEGORY == 0].index

# %%
doc_ids_ham
# Out:
# Int64Index([1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905,
#             ...
#             5786, 5787, 5788, 5789, 5790, 5791, 5792, 5793, 5794, 5795],
#            dtype='int64', name='DOC_ID', length=3900)

# %% [markdown]
# ### Subsetting a Series with an Index

# %%
type(doc_ids_spam)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
type(nested_list)
# Out:
# pandas.core.series.Series

# %%
nested_list_ham = nested_list.loc[doc_ids_ham]
nested_list_spam = nested_list.loc[doc_ids_spam]
nested_list_ham.tail()
# Out:
# DOC_ID
# 5791    [one, work, well, week, te, updat, server, syn...
# 5792    [damien, morton, quot, approv, html, abl, say,...
# 5793    [mon, che, wrote, that, correct, line, ad, rep...
# 5794    [upon, time, manfr, wrote, would, like, instal...
# 5795    [run, pick, use, new, ftoc, button, show, mess...
# Name: MESSAGE, dtype: object

# %%
# Challenge: use python list comprehension and then find the total number of 
# words in our cleaned dataset of spam email bodies. Also find the total number of
# words in normal emails in the dataset. Then find the 10 most common words used in spam.
# Also, find the 10 most common words used in non-spam messages

flat_list_ham = [item for sublist in nested_list_ham for item in sublist]
print('The total number of words in the ham set is: ',len(flat_list_ham))
normal_words_ham = pd.Series(flat_list_ham)
display(normal_words_ham.value_counts().head(10))

flat_list_spam = [item for sublist in nested_list_spam for item in sublist]
print('The total number of words in the spam set is: ',len(flat_list_spam))
normal_words_spam = pd.Series(flat_list_spam)
display(normal_words_spam.value_counts().head(10))
# Out:
# The total number of words in the ham set is:  441855
# http      7563
# use       3633
# list      2880
# one       2371
# get       2282
# mail      2255
# would     2003
# like      1929
# messag    1849
# work      1798
# dtype: int64
# The total number of words in the spam set is:  317499
# http      3097
# email     3090
# free      2585
# click     2058
# receiv    1989
# list      1971
# get       1914
# pleas     1852
# busi      1792
# order     1746
# dtype: int64

# %% [markdown]
# # Creating a Word Cloud

# %%
nltk.download('gutenberg')
nltk.download('shakespeare')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/danatajiri/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package shakespeare to
# [nltk_data]     /Users/danatajiri/nltk_data...
# [nltk_data]   Package shakespeare is already up-to-date!
# True

# %%
word_cloud = WordCloud().generate(email_body)
plt.imshow(word_cloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
example_corpus = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
display(len(example_corpus))
type(example_corpus)
# Out:
# 260819
# nltk.corpus.reader.util.StreamBackedCorpusView

# %%
example_corpus # tokens
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', ...]

# %%
word_list = [''.join(word) for word in example_corpus] # list of words
novel_as_string = ' '.join(word_list) # string of words
novel_as_string
# Out:
# '[ Moby Dick by Herman Melville 1851 ] ETYMOLOGY . ( Supplied by a Late Consumptive Usher to a Grammar School ) The pale Usher -- threadbare in coat , heart , body , and brain ; I see him now . He was ever dusting his old lexicons and grammars , with a queer handkerchief , mockingly embellished with all the gay flags of all the known nations of the world . He loved to dust his old grammars ; it somehow mildly reminded him of his mortality . " While you take in hand to school others , and to teach them by what name a whale - fish is to be called in our tongue leaving out , through ignorance , the letter H , which almost alone maketh the signification of the word , you deliver that which is not true ." -- HACKLUYT " WHALE . ... Sw . and Dan . HVAL . This animal is named from roundness or rolling ; for in Dan . HVALT is arched or vaulted ." -- WEBSTER \' S DICTIONARY " WHALE . ... It is more immediately from the Dut . and Ger . WALLEN ; A . S . WALW - IAN , to roll , to wallow ." -- RIC
# ...

# %%
icon = Image.open(WHALE_FILE)
image_mask = Image.new(mode='RGB',size=icon.size, color =(255,255,255))
image_mask.paste(icon, box=icon)
rgb_array = np.array(image_mask) # converts image object to a an array

word_cloud = WordCloud(mask = rgb_array, background_color = 'white', 
                      max_words = 400, colormap='ocean')

word_cloud.generate(novel_as_string)


plt.figure(figsize=[12,6])
plt.imshow(word_cloud,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Challenge: use the skull image in the lesson resources tto create a word cloud for Shakespeare's play Hamlet

example_corpus_shakespeare = nltk.corpus.shakespeare.words('hamlet.xml')

word_list_shakespeare = [''.join(word) for word in example_corpus_shakespeare] # list of words
novel_as_string_shakespeare = ' '.join(word_list_shakespeare) # string of words


icon_skull = Image.open(SKULL_FILE)
image_mask_skull = Image.new(mode='RGB',size=icon_skull.size, color =(255,255,255))
image_mask_skull.paste(icon_skull, box=icon_skull)
rgb_array_skull = np.array(image_mask_skull) # converts image object to a an array

word_cloud_shakespeare = WordCloud(mask = rgb_array_skull, background_color = 'white', 
                      max_words = 300, colormap='bone')

word_cloud_shakespeare.generate(novel_as_string_shakespeare)


plt.figure(figsize=[12,6])
plt.imshow(word_cloud_shakespeare,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Word Cloud of Ham and Spam Messages

# %%
ham_str = ' '.join(flat_list_ham) # generate the text as a string for the word cloud

thumbs_up_icon = Image.open(THUMBS_UP_FILE)
thumbs_up_image = Image.new(mode='RGB',size=thumbs_up_icon.size, color =(255,255,255))
thumbs_up_image.paste(thumbs_up_icon, box=thumbs_up_icon)
rgb_array_thumbs_up = np.array(thumbs_up_image) # converts image object to a an array

word_cloud_ham = WordCloud(mask = rgb_array_thumbs_up, background_color = 'white', 
                      max_words = 300, colormap='winter')

word_cloud_ham.generate(ham_str)


plt.figure(figsize=[12,6])
plt.imshow(word_cloud_ham,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Challenge: Look at the word cloud documentation. Use the custom font included in the less resources
# instead of the default font and create a word cloud of the spammy words

spam_str = ' '.join(flat_list_spam) # generate the text as a string for the word cloud

thumbs_down_icon = Image.open(THUMBS_DOWN_FILE)
thumbs_down_image = Image.new(mode='RGB',size=thumbs_down_icon.size, color =(255,255,255))
thumbs_down_image.paste(thumbs_down_icon, box=thumbs_down_icon)
rgb_array_thumbs_down = np.array(thumbs_down_image) # converts image object to a an array

word_cloud_spam = WordCloud(font_path = FONT_FILE, mask = rgb_array_thumbs_down, background_color = 'white', 
                      max_words = 300, colormap='autumn')

word_cloud_spam.generate(spam_str)


plt.figure(figsize=[12,6])
plt.imshow(word_cloud_spam,interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Generate Vocabulary & Dictionary

# %%
stemmed_nested_list = data.MESSAGE.apply(clean_msg_no_html)
flat_stemmed_list = [item for sublist in stemmed_nested_list for item in sublist]
# Out:
# /Users/danatajiri/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py:417: MarkupResemblesLocatorWarning: "http://www.post-gazette.com/columnists/20020905brian5
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
unique_words = pd.Series(flat_stemmed_list).value_counts()
print('Nr of uniqe words', unique_words.shape[0])
unique_words.head()
# Out:
# Nr of uniqe words 27330
# http     10660
# use       5019
# list      4851
# email     4367
# get       4196
# dtype: int64

# %%
# Challenge: create subset of the series called 'frequent_words' that only cntains the most common 2,500
# words out of the total. Print oout the top 10 words
frequent_words = unique_words[0:VOCAB_SIZE]

# %%
display(len(frequent_words))
display(type(frequent_words))
print('Most common words: \n', frequent_words[0:10])
# Out:
# 2500
# pandas.core.series.Series
# Most common words:
#  http     10660
# use       5019
# list      4851
# email     4367
# get       4196
# mail      3983
# one       3905
# free      3202
# time      3039
# work      2881
# dtype: int64

# %% [markdown]
# # Create Vocabulary DataFrame with a WORD_ID

# %%
word_ids = list(range(0, VOCAB_SIZE))
vocab = pd.DataFrame({'VOCAB_WORD':frequent_words.index.values}, index = word_ids)
vocab.index.name = 'WORD_ID'
vocab.head()
# Out:
#         VOCAB_WORD
# WORD_ID
# 0             http
# 1              use
# 2             list
# 3            email
# 4              get

# %% [markdown]
# ## Save the Vocabulary as a CSV File

# %%
vocab.to_csv(WORD_ID_FILE, index_label=vocab.index.name, header=vocab.VOCAB_WORD.name)

# %% [markdown]
# # Excercise: Checking if a Word is Part of the Vocabulary

# %%
# Challenge: Write a line of code that checks if a particular word is part of the vocabulary. Your code should
# return True if the word is among the 2500 words that comprise the vocabulary and False otherwise.
# Check these words:
# 'machine'
# 'learning'
# 'fun'
# 'learn'
# 'data'
# 'science'
# 'app'
# 'brewery'

any(vocab.VOCAB_WORD == 'machine') # inefficient
# Out:
# False

# %%
'brewery' in set(vocab.VOCAB_WORD)
# Out:
# False

# %% [markdown]
# # Exercise: Find the Email with the Most Number of Words

# %%
# Challenge: Print out the number of words in the longest email (after cleaning & stemming). Note the
# longest email's position in the list of cleaned emails. Print out the stemmed list of words in the longest
# email. Print out the longest email from the data dataframe

# Hint: use the len() function and practice list comprehension

def find_len(message):
    return len(message)

length_of_messages = nested_list.apply(find_len)
print('The number of words in the longest email: ',length_of_messages.max())
# Out:
# The number of words in the longest email:  7671

# %%
print('The longest email\'s position : ',length_of_messages.idxmax())
# Out:
# The longest email's position :  5401

# %%
print('The stemmed list of words in the longest email: \n', nested_list[length_of_messages.idxmax()])
# Out:
# The stemmed list of words in the longest email:
# ...

# %%
data.MESSAGE[length_of_messages.idxmax()] #Longest email from dataframe
# Out:
# '------------------------ Yahoo! Groups Sponsor ---------------------~-->\n\n4 DVDs Free +s&p Join Now\n\nhttp://us.click.yahoo.com/pt6YBB/NXiEAA/Ey.GAA/26EolB/TM\n\n---------------------------------------------------------------------~->\n\n\n\nA new version of unison is now available for testing.  It incorporates\n\nseveral small improvements over 2.9.1, but the main change is a fix to\n\na bug that had potentially serious safety consequences, but only for\n\nthe very small number of users that are in the habit of running more\n\nthan one instance of Unison at a time, in parallel.  These users are\n\nstrongly encouraged to upgrade.  Others can wait if they wish.\n\n\n\nThe release includes pre-built executables for Linux and Solaris, but\n\nnot Windows.  (We are looking for a Unison-Windows maintainer -- at\n\nthe moment, none of the active developers are regularly using Unison\n\non Windows, and we do not have a machine that is configured properly\n\nfor building executables for e
# ...

# %% [markdown]
# # Generate Features & a Sparse Matrix

# %% [markdown]
# ### Creating a DataFrame with one Word per Column

# %%
display(type(stemmed_nested_list))
display(type(stemmed_nested_list[1]))
# Out:
# pandas.core.series.Series
# list

# %%
word_columns_df = pd.DataFrame.from_records(stemmed_nested_list.tolist())
word_columns_df.head()
# Out:
#      0        1         2       3       4      5       6           7     \
# 0    dear  homeown  interest    rate  lowest  point    year        help
# 1  attent     must    comput    user  packag   deal  norton  systemwork
# 2  messag     mime    format    dare     tri   find  better     annuiti
# 3  import   inform       new  domain    name  final   avail       gener
# 4  bottom     line      give    away      cd   free   peopl        like
#
#        8         9     ...  7661  7662  7663  7664  7665  7666  7667  7668  \
# 0      find      best  ...  None  None  None  None  None  None  None  None
# 1   softwar      suit  ...  None  None  None  None  None  None  None  None
# 2  guarante      year  ...  None  None  None  None  None  None  None  None
# 3    public  discount  ...  None  None  None  None  None  None  None  None
# 4       one     month  ...  None  None  None  None  None  None  None  None
#
#    7669  7670
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# ...

# %%
word_columns_df.shape
# Out:
# (5796, 7671)

# %% [markdown]
# ### Splitting the Data into a Training and Testing Dataset

# %%
# Challenge: Can you split the data into a training and testing set? Set the test size at 30%. The training data
# should include 4057 emails. Use seed value of 42 to shuffle the data.
# What should the target values be?

X_train, X_test, y_train, y_test = train_test_split(word_columns_df, data.CATEGORY, test_size=.3, random_state=42)

# %%
X_train.index.name = X_test.index.name = 'DOC_ID'
display(X_train.head())
display(y_train.head())
# Out:
#           0             1         2       3         4       5          6     \
# DOC_ID
# 4844       thu           jul    rodent   unusu      size   wrote      appli
# 4727      well         would    vaniti    list   forward   least      littl
# 5022     world          wide      word    issu  saturday  august       sent
# 3504    believ  spamassassin  maintain  scheme   wherebi   corpu  distribut
# 3921     sorri         think      send  realiz      list  sender      usual
#
#             7         8      9     ...  7661  7662  7663  7664  7665  7666  \
# DOC_ID                             ...
# 4844         one     three  order  ...  None  None  None  None  None  None
# 4727        pure      data   week  ...  None  None  None  None  None  None
# 5022    saturday  subscrib  least  ...  None  None  None  None  None  None
# 3504          ie     sever  peopl  ...  None  None  None  None  None  None
# 3921      anyawi       ask  harri  ...  None  None  None  None  None  None
#
# ...

# %%
print('Nr of training samples: ', X_train.shape[0])
print('Fraction of training samples: ', X_train.shape[0] / word_columns_df.shape[0])
# Out:
# Nr of training samples:  4057
# Fraction of training samples:  0.6999654934437544

# %% [markdown]
# ### Create a Sparse Matrix for the Training Data

# %%
word_index = pd.Index(vocab.VOCAB_WORD)
display(type(word_index))
type(word_index[3])
# Out:
# pandas.core.indexes.base.Index
# str

# %%
word_index.get_loc('thu')
# Out:
# 392

# %%
def make_sparse_matrix(df,indexed_words,labels):
    '''
    Returns sparse matrix as dataframe.
    
    df: A dataframe with words in the columns with a document id as an idex (X_train or X_test)
    indexed_words: index of words ordered by word_id
    labels: catergory as a series (y_train or y_test)
    '''
    
    nr_rows = df.shape[0]
    nr_cols = df.shape[1]
    word_set = set(indexed_words)
    dict_list = []
    
    for i in range(nr_rows):
        for j in range(nr_cols):
            word = df.iat[i,j]
            if word in word_set:
                doc_id = df.index[i]
                word_id = indexed_words.get_loc(word)
                category = labels.at[doc_id]
                
                item = {'LABEL': category, 'DOC_ID': doc_id, 'OCCURENCE': 1, 'WORD_ID': word_id}
                
                dict_list.append(item)
    
    return pd.DataFrame(dict_list)

# %%
sparse_train_df = make_sparse_matrix(X_train, word_index, y_train)

# %%
sparse_train_df[:5]
# Out:
#    LABEL  DOC_ID  OCCURENCE  WORD_ID
# 0      0    4844          1      392
# 1      0    4844          1      493
# 2      0    4844          1     2362
# 3      0    4844          1      496
# 4      0    4844          1       37

# %%
sparse_train_df.shape
# Out:
# (445755, 4)

# %%
sparse_train_df[-5:]
# Out:
#         LABEL  DOC_ID  OCCURENCE  WORD_ID
# 445750      1     860          1      126
# 445751      1     860          1      645
# 445752      1     860          1      516
# 445753      1     860          1     1394
# 445754      1     860          1     1074

# %% [markdown]
# ### Combine Occurences with the Pandas groupby() Method

# %%
train_grouped = sparse_train_df.groupby(['DOC_ID','WORD_ID','LABEL']).sum()
train_grouped.head()
# Out:
#                       OCCURENCE
# DOC_ID WORD_ID LABEL
# 0      0       1              2
#        7       1              1
#        16      1              1
#        18      1              1
#        24      1              1

# %%
vocab.at[0,'VOCAB_WORD']
# Out:
# 'http'

# %%
train_grouped = train_grouped.reset_index()
display(train_grouped.head())
train_grouped.tail()
# Out:
#    DOC_ID  WORD_ID  LABEL  OCCURENCE
# 0       0        0      1          2
# 1       0        7      1          1
# 2       0       16      1          1
# 3       0       18      1          1
# 4       0       24      1          1
#         DOC_ID  WORD_ID  LABEL  OCCURENCE
# 265869    5795     1829      0          1
# 265870    5795     1897      0          2
# 265871    5795     2126      0          1
# 265872    5795     2274      0          1
# 265873    5795     2486      0          1

# %% [markdown]
# ### Save Training Data as .txt File

# %%
np.savetxt(TRAINING_DATA_FILE, train_grouped, fmt='%d')

# %%
# create sparse matrix for test data
sparse_test_df = make_sparse_matrix(X_test, word_index, y_test)
test_grouped = sparse_test_df.groupby(['DOC_ID','WORD_ID','LABEL']).sum()
test_grouped = test_grouped.reset_index()

np.savetxt(TEST_DATA_FILE, test_grouped, fmt='%d')
