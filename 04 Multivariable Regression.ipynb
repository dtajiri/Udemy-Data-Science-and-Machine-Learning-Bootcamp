# %% [markdown]
# # Notebook imports

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %matplotlib inline

# %% [markdown]
# # Gather Data
# [Source: Original research paper](https://deepblue.lib.umich.edu/bitstream/handle/2027.42/22636/0000186.pdf?sequence=1&isAllowed=y)

# %%
boston_dataset = load_boston()

# %%
type(boston_dataset)
#convert data to datset
# Out:
# sklearn.utils.Bunch

# %%
boston_dataset
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
dir(boston_dataset)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target']

# %%
print(boston_dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# ## Data points and features

# %%
type(boston_dataset.data)
# Out:
# numpy.ndarray

# %%
boston_dataset.data.shape #chaining dot notation
# Out:
# (506, 13)

# %%
boston_dataset.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
# Actual prices in thousands (000s)
boston_dataset.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %% [markdown]
# ## Data exploration with Pandas dataframes

# %%
# Create a pandas dataframe
data = pd.DataFrame(data=boston_dataset.data, columns = boston_dataset.feature_names)

# Add column with price (target)
data['PRICE'] = boston_dataset.target

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %%
data.count() # show us the number of rows (rows are referred to as instances)
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# PRICE      506
# dtype: int64

# %% [markdown]
# ## Clean Data - check for missing values

# %%
pd.isnull(data).any() #null means nothing, not 0
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# PRICE      False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# # Visualizing Data -  Histograms, Distributions and Bar Charts

# %%
plt.figure(figsize = [10,6])
plt.hist(data['PRICE'], bins = 50, ec='black', color='lightblue')
plt.xlabel('Price in 00s')
plt.ylabel('Num of Houses')
plt.show()

# %%
plt.figure(figsize = [10,6])
sns.histplot(data['PRICE'], bins=50, kde=True, color='hotpink')
plt.show()

# %%
plt.figure(figsize=[10,6])
plt.hist(data['RM'], ec='black', color='teal')
plt.xlabel('Average Number of Rooms')
plt.ylabel('Num of Houses')
# Out:
# Text(0, 0.5, 'Num of Houses')

# %%
data['RM'].mean()
# Out:
# 6.284634387351787

# %%
plt.figure(figsize=[10,6])
plt.hist(data['RAD'], bins = 24, ec='black', color='Purple', rwidth=.5)
plt.xlabel('Accessibility to highways')
plt.ylabel('Num of Houses')
# Out:
# Text(0, 0.5, 'Num of Houses')

# %%
data['RAD'].value_counts() #value_counts() will show us how many unique values there are
# Out:
# 24.0    132
# 5.0     115
# 4.0     110
# 3.0      38
# 6.0      26
# 8.0      24
# 2.0      24
# 1.0      20
# 7.0      17
# Name: RAD, dtype: int64

# %%
frequency = data['RAD'].value_counts()
#show us the index values
#frequency.index
#frequency.axes[0]
plt.bar(frequency.index,height=frequency, color='Purple')
plt.xlabel('Accessibility to highways')
plt.ylabel('Num of Houses')
# Out:
# Text(0, 0.5, 'Num of Houses')

# %%
data['CHAS'].value_counts()
# Out:
# 0.0    471
# 1.0     35
# Name: CHAS, dtype: int64

# %% [markdown]
# # Descriptive Statistics

# %%
data['PRICE'].min()
# Out:
# 5.0

# %%
data['PRICE'].max()
# Out:
# 50.0

# %%
data.min()
# Out:
# CRIM         0.00632
# ZN           0.00000
# INDUS        0.46000
# CHAS         0.00000
# NOX          0.38500
# RM           3.56100
# AGE          2.90000
# DIS          1.12960
# RAD          1.00000
# TAX        187.00000
# PTRATIO     12.60000
# B            0.32000
# LSTAT        1.73000
# PRICE        5.00000
# dtype: float64

# %%
data.max()
# Out:
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# CHAS         1.0000
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# PRICE       50.0000
# dtype: float64

# %%
data.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# PRICE       22.532806
# dtype: float64

# %%
data.median()
# Out:
# CRIM         0.25651
# ZN           0.00000
# INDUS        9.69000
# CHAS         0.00000
# NOX          0.53800
# RM           6.20850
# AGE         77.50000
# DIS          3.20745
# RAD          5.00000
# TAX        330.00000
# PTRATIO     19.05000
# B          391.44000
# LSTAT       11.36000
# PRICE       21.20000
# dtype: float64

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Correlation
#
# ### $$ \rho_{XY} = corr(X,Y) $$
#
# ### $$ -1.0 \leq \rho_{XY} \leq +1.0$$

# %%
data['PRICE'].corr(data['RM'])
# Out:
# 0.6953599470715393

# %%
# Challenge: Calculate the correlation between property prices and the pupil teacher ratio
data['PRICE'].corr(data['PTRATIO'])
# Out:
# -0.5077866855375616

# %%
data.corr() ##different type of correlation. default is Pearsons
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
mask = np.zeros_like(data.corr())
triangle_indices = np.triu_indices_from(mask)
mask[triangle_indices] = True

# %%
plt.figure(figsize=[16,10])
sns.heatmap(data.corr(), mask = mask, annot=True, annot_kws={"size": 14}, cmap="YlGnBu") 
#corr is not valid for CHAS and RAD bc theyre not continuous variables
plt.xticks(fontsize=14) 
plt.yticks(fontsize=14)

#todo: Check if DIS adds value to regression
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5]),
#  [Text(0, 0.5, 'CRIM'),
#   Text(0, 1.5, 'ZN'),
#   Text(0, 2.5, 'INDUS'),
#   Text(0, 3.5, 'CHAS'),
#   Text(0, 4.5, 'NOX'),
#   Text(0, 5.5, 'RM'),
#   Text(0, 6.5, 'AGE'),
#   Text(0, 7.5, 'DIS'),
#   Text(0, 8.5, 'RAD'),
#   Text(0, 9.5, 'TAX'),
#   Text(0, 10.5, 'PTRATIO'),
#   Text(0, 11.5, 'B'),
#   Text(0, 12.5, 'LSTAT'),
#   Text(0, 13.5, 'PRICE')])

# %%
#Challenge: Picture the relationship between pollution and distance in your head
# Then create a scatter plot between DIS and NOX
nox_dis_corr = round(data['NOX'].corr(data['DIS']),3)

plt.figure(figsize=[9,6])
plt.scatter(data['DIS'],data['NOX'], alpha=.5, color='indigo')
plt.title(f'DIS vs. NOX (Correlation {nox_dis_corr})')
plt.ylabel("NOX - Nitric Oxide Pollution", fontsize = 14)
plt.xlabel("DIS - Distance from Pollution", fontsize = 14)
# Out:
# Text(0.5, 0, 'DIS - Distance from Pollution')

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.jointplot(x=data['DIS'],y=data['NOX'],height=7, color='indigo', joint_kws={'alpha': .5})

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.jointplot(x=data['DIS'],y=data['NOX'],height=7, color='indigo', joint_kws={'alpha': .5})

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.jointplot(x=data['DIS'],y=data['NOX'],height=7, color='indigo', kind ='hex' )

# %%
sns.set()
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.jointplot(x=data['TAX'],y=data['RAD'],height=7, color='darkred', joint_kws={'alpha': .5})

# %%
sns.lmplot(x = 'TAX', y = 'RAD', data=data, height=7)

# %%
#Challenge: Create a scatter plot bettween the house prices and the number of rooms (RM)
rm_tgt_corr = round(data['RM'].corr(data['PRICE']), 3)

plt.figure(figsize=[9,6])
plt.scatter(data['RM'],data['PRICE'], alpha=.5, color='skyblue' )
plt.title(f'PRICE vs RM (Correlation {rm_tgt_corr})', fontsize = 14)
plt.ylabel('PRICE in thousands', fontsize = 14)
plt.xlabel('RM - Median num of Rooms', fontsize = 14)
# Out:
# Text(0.5, 0, 'RM - Median num of Rooms')

# %%
sns.lmplot(x = 'RM', y = 'PRICE', data=data, height=7)

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, kind='reg', plot_kws={'line_kws': {'color': 'cyan'}})

# %% [markdown]
# # Training & Test Dataset Split

# %%
prices = data['PRICE']
features = data.drop('PRICE', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2, random_state = 10)

# % of training set
len(X_train)/len(features)

# %%
# % of test data set
X_test.shape[0]/features.shape[0]

# %% [markdown]
# # Multivariable Regression

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)

#Challenge: print out r-square for training and testing dataset
print('Traininig data r-squared:', regr.score(X_train,y_train))
print('Test data r-squared:', regr.score(X_test, y_test))
#its normal for performance to lower for the test data, but it shows how our model would work in the real world

print('Intercept', regr.intercept_)
pd.DataFrame(data = regr.coef_, index= X_train.columns, columns=['coef'])

# %% [markdown]
# ## Data Transformations

# %%
data['PRICE'].skew()
#skew of a normal distribution is 0, our data is skewed to the right

# %%
y_log = np.log(data['PRICE'])
y_log.skew()

# %%
sns.set_style('white')
sns.histplot(y_log, bins=50, kde=True, color='hotpink')
plt.title(f'Log price with skew {y_log.skew()}')

# %%
sns.lmplot(x='LSTAT', y='PRICE', data=data, height=7, scatter_kws={'alpha': 0.6}, line_kws={'color': "darkred"})

# %%
transformed_data = features
transformed_data['LOG_PRICE'] = y_log
sns.lmplot(x='LSTAT', y='LOG_PRICE', data=transformed_data, height=7, scatter_kws={'alpha': 0.6}, line_kws={'color': "cyan"})

# %% [markdown]
# ## Regression using log price

# %%
prices = np.log(data['PRICE']) #use log prices
features = data.drop('PRICE', axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2, random_state = 10)

regr = LinearRegression()
regr.fit(X_train, y_train)

print('Traininig data r-squared:', regr.score(X_train,y_train))
print('Test data r-squared:', regr.score(X_test, y_test))

print('Intercept', regr.intercept_)
pd.DataFrame(data = regr.coef_, index= X_train.columns, columns=['coef'])

# %%
# Charles River Property Premium
np.e**(0.080331)

# %% [markdown]
# ## p values & Evaluating Coefficients

# %%
X_incl_const = sm.add_constant(X_train)

model = sm.OLS(y_train, X_incl_const) #OLS --> Ordinary Least Squares
results = model.fit()

#results.params
#results.pvalues
pd.DataFrame({'coef': results.params, 'p-value': round(results.pvalues,3)})
#according to p-values, the INDUS and AGE features aren't very significant

# %% [markdown]
# ## Testing for Multicollinearity
# $$ TAX = \alpha_0 + \alpha_1 RM + \alpha_2 NOX + ... + \alpha_{12} LSTAT$$
# $$ VIF_{TAX} = \frac{1}{(1 - R_{TAX} ^2)}$$

# %%
variance_inflation_factor(exog=X_incl_const.values, exog_idx = 1)

# %%
#Challenge: print out the number of columns in X_incl_const
print(X_incl_const.values.shape[1])
print(len(X_incl_const.columns))

# %%
# Challenge: write a for loop that prints out all the VIFs for all the features
for i in range(len(X_incl_const.columns)):
    print(variance_inflation_factor(exog=X_incl_const.values, exog_idx = i))

# %%
vif_all = [variance_inflation_factor(exog=X_incl_const.values, exog_idx = i)
           for i in range(X_incl_const.shape[1])]
pd.DataFrame({'coef_name': X_incl_const.columns, 'vif': np.round(vif_all,2)})

# %% [markdown]
# # Model Simplification  & BIC

# %%
# Original model with log prices and all features

X_incl_const = sm.add_constant(X_train)

model = sm.OLS(y_train, X_incl_const) #OLS --> Ordinary Least Squares
results = model.fit()

orig_coef = pd.DataFrame({'coef': results.params, 'p-value': round(results.pvalues,3)})

# Challenge: find and check official docs for results object and print out BIC & r-squared
print('R-squared: ', results.rsquared)
print('BIC:', results.bic)

# %%
# reduced model #1 excluding INDUS
X_incl_const = sm.add_constant(X_train)
X_incl_const = X_incl_const.drop(['INDUS'], axis = 1)

model = sm.OLS(y_train, X_incl_const)
results = model.fit()

coef_minus_indus = pd.DataFrame({'coef': results.params, 'p-value': round(results.pvalues,3)})

# Challenge: find and check official docs for results object and print out BIC & r-squared
print('R-squared: ', results.rsquared)
print('BIC:', results.bic)

# results encouraging because the BIC is lower and the goodness of fit stays relatively the same

# %%
# reduced model #2 excluding INDUS and AGE
X_incl_const = sm.add_constant(X_train)
X_incl_const = X_incl_const.drop(['INDUS', 'AGE'], axis = 1)

model = sm.OLS(y_train, X_incl_const)
results = model.fit()

reduced_coef = pd.DataFrame({'coef': results.params, 'p-value': round(results.pvalues,3)})

print('R-squared: ', results.rsquared)
print('BIC:', results.bic)

# results show we can remove INDUS and AGE without much loss. This simplifies our model

# %%
frames = [orig_coef, coef_minus_indus, reduced_coef]
pd.concat(frames,axis=1)

# %% [markdown]
# # Residuals and Residual Plots

# %%
# Modified model: transformed (using log prices) & simplified (dropping two features)
prices = np.log(data['PRICE']) #use log prices
features = data.drop(['PRICE', 'INDUS', 'AGE'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2, random_state = 10)

# Using statsmodel

X_incl_const = sm.add_constant(X_train)
model = sm.OLS(y_train, X_incl_const)
results = model.fit()

# Residuals
#residuals = y_train - results.fittedvalues
#results.resid

#Graph of Actual vs. Predicted Prices
corr = round(y_train.corr(results.fittedvalues),2)

plt.style.use('seaborn-whitegrid')

plt.plot(y_train,y_train, color='cyan')
plt.scatter(x=y_train, y=results.fittedvalues, c = 'navy', alpha = .5)

plt.xlabel('Actual log prices $y_i$', fontsize=14)
plt.ylabel('Predicted log prices $\hat y_i$', fontsize=14)
plt.title(f'Actual vs Predicted log prices: $y_i$ vs $\hat y_i$ (Corr = {corr})', fontsize = 17)

plt.show()

plt.plot(np.e**y_train,np.e**y_train, color='cyan')
plt.scatter(x=np.e**y_train, y=np.e**results.fittedvalues, c = 'blue', alpha = .5)

plt.xlabel('Actual prices 000s $y_i$', fontsize=14)
plt.ylabel('Predicted prices 000s $\hat y_i$', fontsize=14)
plt.title(f'Actual vs Predicted prices: $y_i$ vs $\hat y_i$ (Corr = {corr})', fontsize = 17)

plt.show()

# Residuals vs Predicted values

plt.scatter(x=results.fittedvalues, y=results.resid, c = 'purple', alpha = .5)

plt.xlabel('Predicted log prices $\hat y_i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.title('Residuals vs Fitted Values', fontsize = 17)

plt.show()

#Mean Squared Error & R-Squared
reduced_log_mse = round(results.mse_resid,3)
reduced_log_rsquared = round(results.rsquared, 3)

# %%
# Distributtion of Residuals (log prices) - checking for normality
resid_mean = round(results.resid.mean(),3)
resid_skew = round(results.resid.skew(),3)

sns.histplot(results.resid, color='navy', kde = True)
plt.title(f'Log price model: residuals Skew({resid_skew}) Mean({resid_mean})')
plt.show()

# %%
# Challenge: Using the original model with all the features and normal prices generate:
# Plot of actual vs predicted prices (incl. correlation) using a different color
# Plot of residuals vs. predicted prices
# Plot of distribution of residuals (incl. skew)
# Analyze the results
prices = data['PRICE']
features = data.drop(['PRICE'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.2, random_state = 10)

X_incl_const = sm.add_constant(X_train)

model = sm.OLS(y_train, X_incl_const)
orig_results = model.fit()

#Graph of Actual vs. Predicted Prices
corr = round(y_train.corr(orig_results.fittedvalues),2)

plt.plot(y_train,y_train, color='cyan')
plt.scatter(x=y_train, y=orig_results.fittedvalues, c = 'navy', alpha = .5)

plt.xlabel('Actual prices $y_i$', fontsize=14)
plt.ylabel('Predicted  prices $\hat y_i$', fontsize=14)
plt.title(f'Actual vs Predicted prices: $y_i$ vs $\hat y_i$ (Corr = {corr})', fontsize = 17)

plt.show()

# Residuals vs Predicted values

plt.scatter(x=orig_results.fittedvalues, y=orig_results.resid, c = 'purple', alpha = .5)

plt.xlabel('Predicted prices $\hat y_i$', fontsize=14)
plt.ylabel('Residuals', fontsize=14)
plt.title('Residuals vs Fitted Values', fontsize = 17)

plt.show()

# Distributtion of Residuals (log prices) - checking for normality
orig_resid_mean = round(orig_results.resid.mean(),3)
orig_resid_skew = round(orig_results.resid.skew(),3)

sns.histplot(orig_results.resid, color='navy', kde = True)
plt.title(f'Price model: residuals Skew({orig_resid_skew}) Mean({orig_resid_mean})')
plt.show()

#Mean Squared Error & R-Squared
full_normal_mse = round(orig_results.mse_resid,3)
full_normal_rsquared = round(orig_results.rsquared, 3)

# %%
X_incl_const

# %%
pd.DataFrame({'R-Squared': [reduced_log_rsquared, full_normal_rsquared], 
              'MSE' : [reduced_log_mse, full_normal_mse], 
              'RMSE': np.sqrt([reduced_log_mse, full_normal_mse])
             }, index=['Reduced Log Model', 'Full Normal Price Model'],)

# scale of the MSE is dependent on the data.
# lower values of MSE means better fit, but one is in log and one is normal

# %%
# Challenge: Our estimate for a house price is $30,000. Calculate the upper and lower bound
# for a 95% prediction interval using the reduced log model

print('1 std in log prices is: ', np.sqrt(reduced_log_mse))
print('2 std in log prices is: ', 2*np.sqrt(reduced_log_mse))
print('Upper bound in log is: ', np.log(30) + 2 *np.sqrt(reduced_log_mse))
print('Upper bound in normal prices is: ', np.e**(np.log(30) + 2 *np.sqrt(reduced_log_mse)) *1000)
print('Lower bound in log is: ', np.log(30) - 2 *np.sqrt(reduced_log_mse))
print('Lower bound in normal prices is: ', np.e**(np.log(30) - 2 *np.sqrt(reduced_log_mse))*1000)
