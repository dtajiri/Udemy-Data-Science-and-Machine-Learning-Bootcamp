# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import recall_score, precision_score, f1_score

# %%
DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'

# %%
data = pd.read_json(DATA_JSON_FILE)

# %%
data.tail()
# Out:
#       CATEGORY                                            MESSAGE  \
# 5791         0  I'm one of the 30,000 but it's not working ver...
# 5792         0  Damien Morton quoted:\n\n>W3C approves HTML 4 ...
# 5793         0  On Mon, 2002-07-22 at 06:50, che wrote:\n\n\n\...
# 5794         0  Once upon a time, Manfred wrote :\n\n\n\n> I w...
# 5795         0  If you run Pick, and then use the "New FTOC" b...
#
#                                    FILE_NAME
# 5791  00609.dd49926ce94a1ea328cce9b62825bc97
# 5792  00957.e0b56b117f3ec5f85e432a9d2a47801f
# 5793  01127.841233b48eceb74a825417d8d918abf8
# 5794  01178.5c977dff972cd6eef64d4173b90307f0
# 5795  00747.352d424267d36975a7b40b85ffd0885e

# %%
data.sort_index(inplace = True) #order data by index

# %%
vectorize = CountVectorizer(stop_words = 'english')

# %%
all_features = vectorize.fit_transform(data.MESSAGE) # gives sparse matrix

# %%
all_features.shape
# Out:
# (5796, 102688)

# %%
vectorize.vocabulary_
# Out:
# {'dear': 32719,
#  'homeowner': 48032,
#  'rates': 76346,
#  'lowest': 59361,
#  'point': 72293,
#  '40': 7824,
#  'years': 98500,
#  'help': 47198,
#  'best': 23129,
#  'rate': 76343,
#  'situation': 82313,
#  'matching': 60926,
#  'needs': 64746,
#  'hundreds': 48605,
#  'lenders': 58017,
#  'home': 48004,
#  'improvement': 51397,
#  'refinance': 77070,
#  'second': 80964,
#  'mortgage': 63022,
#  'equity': 38990,
#  'loans': 59054,
#  'perfect': 70474,
#  'credit': 30975,
#  'service': 81355,
#  '100': 1496,
#  'free': 42771,
#  'owners': 68711,
#  'new': 64984,
#  'buyers': 25617,
#  'obligation': 66809,
#  'just': 55046,
#  'quick': 75543,
#  'simple': 82167,
#  'form': 42423,
#  'jump': 54997,
#  'start': 84130,
#  'future': 43328,
#  'plans': 71935,
#  'today': 88034,
#  'visit': 92916,
#  'http': 48495,
#  '61': 10092,
#  '145': 2275,
#  '116': 1873,
#  '186': 2748,
#  'user0201': 91334,
#  'index': 51637,
#  'asp': 20429,
#  'afft': 17606,
#  'qm10': 75104,
#  'unsubscribe': 90950,
#  'light': 58468,
#  'watch': 94276,
#  'attention': 20740,
#  'computer': 29755,
#  'users': 91362,
#  'special': 83496,
#  'package': 69115,
#  'deal': 32703,
#  'norton': 65829,
#  'systemworks': 85738,
#  '2002': 3508,
#  'software': 83089,
#  'suite': 85005,
#  'professional': 73360,
#  'edition': 37555,
#  'includes': 51527,
#  'yes': 98548,
#  'feature': 41056,
#  'packed': 69123,
#  'utilities': 91469,
#  'low': 59351,
#  'price': 73132,
#  'protect': 73608,
#  'unwanted': 91006,
#  'hazardous': 46861,
#  'viruses': 92882,
#  'secure': 81008,
#  'private': 73224,
#  'valuable': 92052,
#  'information': 51873,
#  'allow': 18722,
#  'transfer': 88551,
#  'files': 41538,
#  'send': 81174,
#  'mails': 60400,
#  'safely': 80075,
#  'backup': 22191,
#  'data': 32319,
#  'easily': 37275,
#  'improve': 51394,
#  'pc': 69752,
#  'performance': 70482,
#  'superior': 85119,
#  'integral': 52272,
#  'diagnostics': 33895,
#  'great': 45563,
#  '300': 5594,
#  'combined': 29424,
#  'retail': 77954,
#  'value': 92055,
#  '29': 4793,
#  '99': 13970,
#  'shipping': 81773,
#  'don': 34992,
#  'fall': 40611,
#  'prey': 73126,
#  'destructive': 33432,
#  'hackers': 46443,
#  'delay': 33048,
#  'copy': 30455,
#  'euro': 39422,
#  'specialdiscounts4u': 83498,
#  'com': 29405,
#  'email': 38216,
#  'screened': 80742,
#  'filtered': 41573,
#  'house': 48260,
#  'opt': 67891,
#  'compliance': 29680,
#  'state': 84166,
#  'laws': 57666,
#  'wish': 95685,
#  'mailing': 60377,
#  'lists': 58729,
#  'thousands': 87415,
#  'providers': 73660,
#  'dvd': 36559,
#  'optoutd': 67949,
#  'html': 48470,
#  'multi': 63625,
#  'message': 61676,
#  'mime': 62136,
#  'format': 42433,
#  '_nextpart_000_1cdc19_01c25366': 15065,
#  '4b57f3a0': 8446,
#  'content': 30249,
#  'type': 89366,
#  'text': 86986,
#  'plain': 71908,
#  'charset': 27796,
#  'windows': 95597,
#  '1252': 2025,
#  'encoding': 38472,
#  'quoted': 75611,
#  'printable': 73188,
#  'dare': 32275,
#  'try': 88909,
#  'better': 23177,
#  'annuity': 19372,
#  '20': 3486,
#  'guaranteed': 45871,
#  '0a': 913,
#  'year': 98493,
#  'surrender': 85247,
#  'charge': 27776,
#  'agent': 17767,
#  'commission': 29509,
#  'age': 17749,
#  '80': 12020,
#  '09': 844,
#  '800': 12021,
#  '888': 12834,
#  '7641': 11385,
#  'ext': 40021,
#  '103': 1629,
#  'mail': 60308,
#  'phone': 71307,
#  'city': 28382,
#  'pmg': 72163,
#  'financial': 41596,
#  'services': 81357,
#  'deposits': 33268,
#  '000': 1,
#  '25': 4433,
#  'totalling': 88265,
#  '999': 14021,
#  'want': 94154,
#  'receive': 76779,
#  'mailings': 60381,
#  'does': 34891,
#  'communication': 29550,
#  'sent': 81219,
#  'insurance': 52247,
#  'professionals': 73365,
#  'removed': 77478,
#  'list': 58676,
#  'reply': 77615,
#  'instead': 52202,
#  'www': 96525,
#  'insuranceiq': 52248,
#  'optout': 67946,
#  'legal': 57960,
#  'notice': 65884,
#  'insiq': 52134,
#  'htm': 48467,
#  'iso': 53092,
#  '8859': 12828,
#  'head': 47009,
#  'title': 87720,
#  'meta': 61697,
#  'equiv': 38991,
#  '3d': 6385,
#  '3diso': 7050,
#  'body': 24390,
#  'bgcolor': 23297,
#  '666666': 10388,
#  '000000': 4,
#  'font': 42255,
#  'face': 40496,
#  'arial': 20116,
#  'helvetica': 47218,
#  'sans': 80252,
#  'serif': 81300,
#  'table': 86115,
#  'width': 95482,
#  '550': 9237,
#  'border': 24581,
#  'align': 18634,
#  'center': 27405,
#  'cellpadding': 27375,
#  'cellspacing': 27383,
#  'bordercolor': 24584,
#  'ffffff': 41321,
#  'tr': 88437,
#  'td': 86543,
#  'img': 51210,
#  'src': 83867,
#  'iiq': 50894,
#  'images': 51164,
#  '20020822': 3574,
#  '101': 1549,
#  'gif': 44642,
#  'alt': 18803,
#  'height': 47155,
#  '55': 9236,
#  'br': 24813,
#  '102': 1573,
#  'jpg': 54779,
#  '47': 8247,
#  '248': 4390,
#  '201': 3671,
#  '32': 5755,
#  '142': 2255,
#  '202': 3687,
#  '10': 1495,
#  '508': 8989,
#  'size': 82342,
#  '535': 9143,
#  '115': 1857,
#  '95': 13787,
#  'method': 61733,
#  'post': 72586,
#  'action': 16898,
#  '65': 10286,
#  '217': 3962,
#  '159': 2436,
#  'response': 77868,
#  'background': 22154,
#  'colspan': 29390,
#  '15': 2339,
#  'right': 78418,
#  'input': 52069,
#  'contactname': 30214,
#  '50': 8926,
#  'rowspan': 79049,
#  'valign': 92041,
#  'middle': 62018,
#  'q3': 74524,
#  '43': 8047,
#  '30': 5593,
#  'nbsp': 64557,
#  'submit': 84807,
#  'btnsubmit': 25292,
#  'hidden': 47504,
#  'hdnrecipienttxt': 46978,
#  'rhock': 78309,
#  'pmgsecurities': 72166,
#  'hdnsubjecttxt': 46979,
#  'ad': 16973,
#  'inquiry': 52082,
#  'sentto': 81231,
#  '304704': 5623,
#  '416': 7965,
#  'cccccc': 27141,
#  'href': 48388,
#  'important': 51354,
#  'domain': 34956,
#  'names': 64364,
#  'finally': 41589,
#  'available': 21047,
#  'general': 44236,
#  'public': 74009,
#  'discount': 34270,
#  'prices': 73139,
#  'register': 77171,
#  'exciting': 39714,
#  'biz': 23754,
#  'info': 51834,
#  'original': 68108,
#  'net': 64864,
#  '14': 2224,
#  'brand': 24872,
#  'extensions': 40037,
#  'recently': 76796,
#  'approved': 19837,
#  'icann': 49698,
#  'rights': 78429,
#  'biggest': 23562,
#  'benefit': 23038,
#  'course': 30683,
#  'currently': 31433,
#  'easier': 37272,
#  'attractive': 20763,
#  'easy': 37289,
#  'remember': 77422,
#  'affordable': 17601,
#  'domains': 34965,
#  'registration': 77181,
#  'fees': 41108,
#  'include': 51525,
#  'access': 16655,
#  'use': 91310,
#  'control': 30335,
#  'panel': 69304,
#  'manage': 60588,
#  'sincerely': 82203,
#  'administrator': 17205,
#  'remove': 77463,
#  'address': 17095,
#  'promotional': 73488,
#  'company': 29579,
#  'click': 28719,
#  'centralremovalservice': 27420,
#  'cgi': 27613,
#  'bin': 23627,
#  'g1': 43560,
#  'ss2': 83910,
#  '5592oxer3': 9274,
#  '424uqkh2259kcdl5': 8017,
#  '189geil31': 2775,
#  'line': 58564,
#  'away': 21243,
#  'cd': 27206,
#  'people': 70437,
#  'like': 58497,
#  'month': 62904,
#  'let': 58079,
#  'talk': 86251,
#  'product': 73333,
#  'samples': 80191,
#  'earn': 37247,
#  '45': 8150,
#  'days': 32422,
#  'think': 87322,
#  'kidding': 56077,
#  'earned': 37249,
#  'precisely': 72887,
#  '26': 4538,
#  '087': 808,
#  '58': 9372,
#  '94': 13749,
#  'doing': 34927,
#  'scanned': 80499,
#  'checks': 27877,
#  'online': 67661,
#  'eyes': 40137,
#  've': 92277,
#  'tweaked': 89236,
#  'things': 87319,
#  'little': 58761,
#  'busy': 25579,
#  'aren': 20082,
#  'good': 45234,
#  'talking': 86257,
#  'work': 96027,
#  'time': 87620,
#  'helped': 47200,
#  'julie': 54985,
#  '750': 11318,
#  'week': 95081,
#  'jeff': 54089,
#  '6500': 10288,
#  'weeks': 95090,
#  'exact': 39641,
#  'business': 25553,
#  'plan': 71916,
#  'tell': 86768,
#  'exactly': 39642,
#  'expect': 39884,
#  'starting': 84134,
#  'guesswork': 45905,
#  'seriously': 81303,
#  'evaluate': 39462,
#  'happy': 46651,
#  'fly': 42065,
#  'los': 59287,
#  'angeles': 19243,
#  'expense': 39907,
#  'closer': 28825,
#  'look': 59217,
#  'following': 42231,
#  'postal': 72590,
#  'number': 66242,
#  'area': 20071,
#  'code': 29201,
#  'mailto': 60408,
#  'cashflows99': 26900,
#  'excite': 39710,
#  'subject': 84784,
#  'free_cd': 42778,
#  'senate': 81170,
#  '1618': 2477,
#  'section': 80994,
#  '301': 5607,
#  'states': 84179,
#  'statement': 84177,
#  'transmissions': 88598,
#  'unsolicited': 90934,
#  'commercial': 29498,
#  'electronic': 38071,
#  'recipient': 76823,
#  'person': 70601,
#  'initiates': 51976,
#  'transmission': 88597,
#  'stopped': 84448,
#  'cost': 30578,
#  'sending': 81189,
#  'originating': 68116,
#  'word': 96011,
#  '_nextpart_000_00b8_51e06b6a': 15002,
#  'c8586b31': 26321,
#  'base64': 22487,
#  'sgvyzsdzihrozsbob3r0zxn0ihroaw5nigluierwrhmuie5vdyb5b3ugy2fu': 81561,
#  'ig1ha2ugysbwzxjzb25hbcbiywnrdxancmnvchkgb2ygysbevkqgcmlnahqg': 50345,
#  'b250bybdrc1sliagt3vyicjib3qiig5ldybzb2z0d2fyzsblyxnpbhkgdgfr': 21685,
#  'zxmgew91ihrocm91z2gncnrozsbzdgvwcyb0bybtywtligegy29wesbvzib5': 101284,
#  'b3vyig93bibevkrzlg0kdqpot1cgsu5dtfveruqgrk9siezsruuhienvchkg': 21923,
#  'uexbwvnuqvrjt04sie1vu0ldl01qm3mgyw5kigfsbcbtb2z0d2fyzs4ncg0k': 89901,
#  'lsbtdgvwigj5ifn0zxagsw50zxjhy3rpdmugsw5zdhj1y3rpb25zia0klsbb': 59520,
#  'bgwgu29mdhdhcmugvg9vbhmgsw5jbhvkzwqgt24gq0qgdqotie5vierwrcbc': 23387,
#  'dxjuzxigumvxdwlyzwqgdqotiezsruugtgl2zsbuzwnobmljywwgu3vwcg9y': 36708,
#  'dcanci0gmzagrgf5ifjpc2sgrnjlzsbucmlhbcbbdmfpbgfibgugdqotiezs': 32518,
#  'ruugrhzkie1vdmllig9mihlvdxigy2hvawnlichmsu1jveveifrjtuugt0zg': 79504,
#  'rvihkq0kdqpxzsboyxzliefsbcb0agugc29mdhdhcmugew91ig5lzwqgdg8g': 79541,
#  'q09qwsb5b3vyig93bibevkqgtw92awvzlg0kdqpodhrwoi8vc2ftlm1vdghv': 74434,
#  'c3quy29tl3bvcy9kdmquahrtdqorkysrkysrkysrkysrkysrkysrkysrkysr': 26178,
#  'kysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysr': 57054,
#  'kysrkysrdqpuaglzigvtywlsighhcybizwvuihnjcmvlbmvkigfuzcbmawx0': 57046,
#  'zxjlzcbiesbvdxigaw4gag91c2ugiijpufqtt1vuiiigc3lzdgvtigluia0k': 101267,
#  'y29tcgxpyw5jzsb3axroihn0yxrligxhd3muielmihlvdsb3axnoihrvicjp': 98037,
#  'ufqtt1vuiibmcm9tihroaxmgbwfpbgluzybhcyb3zwxsia0kyxmgdghligxp': 89941,
#  'c3rzig9mihrob3vzyw5kcyagb2ygb3rozxigzw1hawwgchjvdmlkzxjzihbs': 26187,
#  'zwfzzsb2axnpdcagdqoncmh0dha6ly9zyw0ubw90ag9zdc5jb20vcg9zl29w': 101122,
#  'dg91dgquahrtba0kkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysr': 33618,
#  'kysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkysrkw0k': 57053,
#  'odqyovplwm01ltu4ngjsyw4yodi2enhhrdetmtm4qm1uvdywothuswnvny0y': 67051,
#  'mjbyawtnmzyymgw1mg': 62408,
#  'style': 84718,
#  'css': 31256,
#  '12px': 2094,
#  'color': 29367,
#  'navy': 64513,
#  'hello': 47191,
#  'chinese': 28004,
#  'traditional': 88497,
#  'div': 34529,
#  '376px': 6125,
#  '195px': 2861,
#  'left': 57946,
#  '238px': 4304,
#  'position': 72559,
#  'absolute': 16491,
#  'visibility': 92910,
#  'visible': 92911,
#  'lime': 58530,
#  'id': 49826,
#  'layer3': 57681,
#  '73px': 11259,
#  '14px': 2334,
#  '172px': 2616,
#  'olive': 67490,
#  'layer2': 57680,
#  '39px': 6238,
#  '13px': 2215,
#  '149px': 2323,
#  '239px': 4313,
#  'silver': 82137,
#  'layer1': 57679,
#  'óà': 102406,
#  '¼þ': 101663,
#  'ª21êà¼o': 101438,
#  'îóðð': 102291,
#  'µäðû': 101526,
#  '½ê½': 101690,
#  'äúïë': 101925,
#  'µø10èfèëí': 101550,
#  'ìöªµàäúµä': 102204,
#  'ì½ýµäðû': 102192,
#  'äúµäæó': 101921,
#  'äúïëôúéì': 101927,
#  'öð²½²½': 102531,
#  'ïè': 102306,
#  'äúïëò': 101926,
#  'íóð': 102240,
#  'ôúéì': 102482,
#  'ô½': 102466,
#  'íô½': 102242,
#  'àµäõ': 101744,
#  '²é': 101462,
#  'íã': 102225,
#  '¾wâ': 101706,
#  'än': 101888,
#  'þ³é': 102667,
#  'iän': 53547,
#  '½ê½µäö': 101691,
#  'øe': 102554,
#  'êç¾wéï': 102132,
#  'î³': 102256,
#  'óãò²êç': 102414,
#  'óãµä¹': 102411,
#  '¾ß': 101713,
#  'æäìøüc': 101970,
#  'º¹': 101603,
#  'rð': 79762,
#  'ñµí': 102342,
#  'þemarketer¹àó': 102659,
#  'ãà': 101866,
#  'øóð61': 102566,
#  'µäöðµèò': 101530,
#  'ë¾½': 102161,
#  'óãë': 102412,
#  '¼þßmðð': 101666,
#  'æã½ówæ½¾ù': 101969,
#  'ªâê': 101449,
#  'èý': 102067,
#  'average': 21070,
#  'ranges': 76282,
#  'æõí': 101983,
#  'ºá': 101610,
#  'ù¹ã': 102591,
#  'banner': 22378,
#  'ads': 17283,
#  'ðå¼þ': 102319,
#  'direct': 34154,
#  'ff0080': 41237,
#  '¼þ³öêû': 101664,
#  'ùiè': 102584,
#  'çòà': 102030,
#  '¼þµøö': 101665,
#  '1000èf': 1517,
#  '500hk': 8936,
#  '9000èf': 13587,
#  '3600hk': 6040,
#  'ùiïã': 102585,
#  'ûà': 102620,
#  '10èf': 1797,
#  '400hk': 7841,
#  'ûè': 102621,
#  '325èf': 5792,
#  '5500hk': 9240,
#  'jjyx': 54382,
#  'serve': 81336,
#  'hk1': 47720,
#  'txt': 89327,
#  'target': 86344,
#  '_blank': 14794,
#  '21px': 3993,
#  'ff0000': 41233,
#  'download': 35152,
#  'ùiå_': 102583,
#  '³à': 101488,
#  '³è': 101490,
#  '201èf': 3686,
#  '4500hk': 8155,
#  'wd': 94712,
#  'taiwan': 86207,
#  '0080ff': 269,
#  'lëí': 59971,
#  'æà': 101967,
#  'úàí': 102609,
#  '20èfæð': 3892,
#  '_âê90': 15350,
#  'òôéï': 102384,
#  'üöüèº': 102637,
#  'öü60èf': 102553,
#  '2500hk': 4438,
#  'öü100èf': 102552,
#  '4000hk': 7833,
#  'c¾wõ¾èõôl': 31832,
#  'ìáéý2000òôéï': 102196,
#  'üôâèº': 102636,
#  'ôâ500èf': 102472,
#  '9500hk': 13791,
#  'ìáéý5000òôéï': 102197,
#  'ff8040': 41258,
#  '¼þü': 101670,
#  'ów': 102391,
#  'span': 83445,
#  'lang': 57480,
#  'en': 38432,
#  '9pt': 14429,
#  '0000c4': 47,
#  'mso': 63435,
#  'fareast': 40694,
#  'family': 40649,
#  'pmingliu': 72170,
#  'language': 57496,
#  'zh': 100264,
#  'tw': 89219,
#  '70': 11063,
#  'ascii': 20348,
#  'times': 87636,
#  'roman': 78892,
#  'hansi': 46632,
#  'ðnì': 102315,
#  'èº': 102049,
#  'ëñë': 102178,
#  'ñü': 102358,
#  '2200': 3999,
#  'hk': 47718,
#  '0000bf': 46,
#  'äã': 101902,
#  'ô¼º': 102464,
#  'íóðò': 102241,
#  'íêéæµäë': 102234,
#  '¼þèº': 101667,
#  'ñïµ½y': 102354,
#  'óðòâõßçëà': 102441,
#  'ðåáªïµ': 102320,
#  'yhzx599': 98667,
#  'vip': 92839,
#  'sina': 82198,
#  'òýçæô': 102388,
#  'ôµçê': 102462,
#  'öµ': 102518,
#  'ìø': 102205,
#  'r2200': 75902,
#  'ãyºóö': 101855,
#  'ðç': 102322,
#  'íäúµçê': 102229,
#  'çò6000': 102027,
#  'îäëñë': 102274,
#  'òýçæ': 102387,
#  'ßm200': 101729,
#  'öðîäëñë': 102543,
#  'äãµä¾wõ¾ïí': 101903,
#  'uè': 91756,
#  'çò': 102026,
#  'mailµøö': 60447,
#  'ôú': 102478,
#  'µø': 101549,
#  'µä': 101516,
#  'µá': 101513,
#  'ïã': 102302,
#  'ª32525642': 101439,
#  'sample': 80189,
#  'å_': 101932,
#  'ª20012356': 101437,
#  'ª9000èf': 101440,
#  'èíâéï': 102060,
#  'óðð': 102439,
#  'µäemailî': 101517,
#  'ùyáï': 102586,
#  'éòô': 102112,
#  'ôµäðèòª': 102461,
#  'ôúö': 102484,
#  'µäµø': 101519,
#  'óò': 102445,
#  'ðð': 102331,
#  'iî': 53554,
#  'eµè': 40210,
#  'ùðôí': 102599,
#  'åë': 101950,
#  'èç': 102054,
#  'ºäãïë': 101612,
#  'ä³µø10èfèëò': 101894,
#  'ììö': 102201,
#  '¼öªµàäãµä': 101654,
#  'aæ': 21585,
#  'ùyó': 102587,
#  'äç': 101909,
#  '¼þí': 101668,
#  'å¾íêçäã': 101942,
#  'îºãµä½â': 102262,
#  'ëüµä': 102181,
#  'ñêçëùóð': 102352,
#  'ãº': 101858,
#  'ñöð': 102357,
#  'îµí': 102260,
#  'óöêç': 102452,
#  'cóöã': 31834,
#  'rã': 79737,
#  '¼µè': 101639,
#  'ýöøäã': 102658,
#  'ò²ôsäãõýêçóãáëß': 102361,
#  'óµä': 102396,
#  'ãºêö': 101859,
#  'åáëëùóðµä': 101943,
#  'êö': 102142,
#  'ús': 102604,
#  'ìðð': 102203,
#  'äãµäæó': 101904,
#  'ë¾á': 102162,
#  'õæîõéì': 102500,
#  'ã½µäãüã': 101861,
#  'æe': 101961,
#  'êçæõí': 102134,
#  'än½': 101889,
#  'iëù²': 53552,
#  'äü': 101929,
#  'mµä': 64087,
#  'àm¼': 101735,
#  '¾¹': 101711,
#  'ë¾': 102159,
#  'äêâ¾wâ': 101916,
#  'àäê': 101755,
#  'ðû': 102335,
#  'èî': 102061,
#  '¾óöð': 101723,
#  'øµúëä': 102558,
#  'ó¾wâ': 102405,
#  'æéìö': 101975,
#  'îò': 102287,
#  'óð': 102432,
#  'étµä¼¼ðgèë': 102084,
#  'tºí': 89433,
#  'ßëù': 101731,
#  'iµä': 53544,
#  'õïµ½y': 102506,
#  'äêâ': 101915,
#  'ëí': 102174,
#  'iìá¹': 53553,
#  'îñ': 102286,
#  '½ý': 101700,
#  'mòâµä': 64099,
#  'ðèçó': 102326,
#  'ôõ': 102477,
#  'üc': 102623,
#  'ôß': 102468,
#  'ñy': 102336,
#  'àmà': 101736,
#  'ïä': 102303,
#  'íðåõ': 102238,
#  'äúðèòªµä': 101928,
#  'õåcâ': 102496,
#  'àm': 101734,
#  'íäú': 102228,
#  'å_µø': 101933,
#  'èîºî': 102062,
#  'ø¼ò¾ù': 102560,
#  'éµ½': 102091,
#  'µøãyððë': 101552,
#  '3ììµ½': 7823,
#  'ðèµ½': 102325,
#  'µøãyððþkàíë': 101553,
#  'english': 38599,
#  'benificiary': 23047,
#  'customer': 31476,
#  'wangjingjing': 94143,
#  'bank': 22360,
#  'china': 27993,
#  'mianyang': 61932,
#  'branch': 24868,
#  '8209': 12183,
#  '9802': 13918,
#  '0003': 108,
#  '158': 2428,
#  'tel': 86714,
#  '0816': 788,
#  '6623109': 10358,
#  'öðîä': 102540,
#  'õõ': 102507,
#  'êõ': 102141,
#  'èë': 102059,
#  'íõ¾': 102243,
#  'îãyðð': 102271,
#  'öð': 102530,
#  'øãyðð¾dê': 102562,
#  'öðð': 102546,
#  'îèëë': 102279,
#  'º0816': 101594,
#  'îµ½ááîò': 102259,
#  'äúìá¹': 101924,
#  'mòâ': 64098,
#  'gó': 46200,
#  'íðå': 102237,
#  'íë': 102235,
#  'öjô': 102510,
#  'º0086': 101592,
#  'ðç¾wâ': 102323,
#  'óðïþ¹': 102438,
#  'ë¾µøö': 102160,
#  'ºöð': 101631,
#  'óê': 102424,
#  '¾dê': 101702,
#  'º¾wâ': 101607,
#  'íæ': 102230,
#  '¾wõ¾½': 101708,
#  'ôo': 102459,
#  'ãû': 101885,
#  '¾wí': 101707,
#  '¼ä': 101645,
#  'µãû': 101515,
#  'õég': 102504,
#  'lõ¹µè': 59972,
#  'råxµíá': 79738,
#  'hr': 48371,
#  'secured': 81009,
#  'investements': 52588,
#  '625': 10154,
#  'tbody': 86457,
#  'green': 45581,
#  'wealth': 94942,
#  'risk': 78493,
#  'black': 23893,
#  'discover': 34281,
#  'kept': 55825,
#  'secret': 80977,
#  'america': 18952,
#  '006600': 249,
#  '515': 9040,
#  'ccffcc': 27154,
#  '99ff00': 14041,
#  '339900': 5897,
#  'verdana': 92410,
#  'turning': 89142,
#  '003300': 219,
#  'oklahoma': 67427,
#  'craig': 30889,
#  'talkington': 86258,
#  'purchased': 74120,
#  'tax': 86409,
#  'lien': 58430,
#  'acre': 16869,
#  'parcel': 69401,
#  'owner': 68710,
#  'failed': 40567,
#  'pay': 69681,
#  'taxes': 86414,
#  'forfeited': 42379,
#  'short': 81850,
#  'later': 57586,
#  'sold': 83116,
#  'property': 73536,
#  'neighbors': 64788,
#  'kind': 56134,
#  'money': 62836,
#  'buys': 25623,
#  'cars': 26860,
#  'sends': 81193,
#  'young': 98995,
#  'college': 29332,
#  'didn': 33961,
#  'stop': 84423,
#  'bought': 24659,
#  '17': 2583,
#  'track': 88460,
#  'ended': 38505,
#  'know': 56457,
#  'making': 60529,
#  'kinds': 56143,
#  'profits': 73388,
#  'change': 27718,
#  'peoples': 70438,
#  'lives': 58780,
#  'solve': 83152,
#  'problems': 73275,
#  'make': 60511,
#  'lot': 59300,
#  '000033': 29,
#  'janice': 53835,
#  'knetzger': 56420,
#  'turned': 89139,
#  '463': 8217,
#  '00': 0,
#  'investment': 52603,
#  'wayne': 94334,
#  'robertson': 78794,
#  'paid': 69199,
#  'todd': 88039,
#  'beemer': 22886,
#  '21': 3894,
#  '500': 8927,
#  '150': 2340,
#  '530': 9119,
#  'investors': 52608,
#  'entrepreneurs': 38757,
#  'consultantion': 30170,
#  'qualify': 75449,
#  '250': 4434,
#  '400': 7825,
#  'required': 77709,
#  'field': 41486,
#  'bordercolordark': 24585,
#  '333300': 5866,
#  '600': 10039,
#  'bordercolorlight': 24586,
#  'ffffcc': 41317,
#  'taxsale06': 86421,
#  'btamail': 25250,
#  'cn': 29033,
#  'investment_inquiry': 52604,
#  'enctype': 38491,
#  'select': 81102,
#  '475': 8265,
#  'liens': 58431,
#  'deeds': 32898,
#  'directly': 34167,
#  'support': 85174,
#  'local': 59071,
#  'departments': 33231,
#  'police': 72334,
#  'schools': 80610,
#  'roads': 78765,
#  'hospitals': 48199,
#  'thank': 87157,
#  'removes': 77489,
#  'centralmailer': 27419,
#  'remove_investment': 77472,
#  '4589dfsl1': 8185,
#  '151rzeh9359iyoc9': 2375,
#  '006fl29': 257,
#  'ffccff': 41285,
#  'free4pornlovers': 42776,
#  'simply': 82178,
#  'amateur': 18895,
#  '990000': 13973,
#  '660066': 10347,
#  '9933ff': 13989,
#  'girl': 44711,
#  'door': 35041,
#  'xxx': 97876,
#  'tour': 88294,
#  'ff0099': 41238,
#  'photos': 71357,
#  'sneeky': 82923,
#  'cams': 26601,
#  'nude': 66211,
#  'exibitionists': 39815,
#  'cheating': 27848,
#  'wives': 95723,
#  'girlfriends': 44713,
#  'pl': 71885,
#  'generator': 44256,
#  'microsoft': 61999,
#  'frontpage': 43003,
#  'progid': 73402,
#  'editor': 37557,
#  'document': 34867,
#  'answer': 19413,
#  'link': 58597,
#  'vlink': 93062,
#  '333399': 5870,
#  'alink': 18642,
#  'collapse': 29305,
#  '425074': 8020,
#  '586': 9389,
#  'autonumber1': 20991,
#  '627': 10161,
#  'emails': 38248,
#  'redirect': 76968,
#  '440': 8097,
#  '390': 6184,
#  'noshade': 65845,
#  '90': 13579,
#  'd76f3a': 32031,
#  'unlist': 90802,
#  '78': 11460,
#  '105': 1703,
#  '304d71': 5624,
#  'brought': 25120,
#  'current': 31422,
#  'federal': 41077,
#  'newwin': 65087,
#  'receiving': 76790,
#  'registered': 77175,
#  'offers': 67164,
#  'marketing': 60794,
#  'partner': 69519,
#  'screening': 80744,
#  'addresses': 17113,
#  'knowledge': 56462,
#  'honor': 48094,
#  'requests': 77707,
#  '72': 11179,
#  'hours': 48259,
#  'received': 76780,
#  'error': 39109,
#  'apologize': 19713,
#  'inconvenience': 51564,
#  'caused': 27013,
#  'unlisted': 90804,
#  'database': 32322,
#  'redirect2': 76969,
#  'forwarded': 42509,
#  'provide': 73656,
#  'old': 67456,
#  '602': 10053,
#  ...}

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, data.CATEGORY, test_size = 0.3, random_state = 88)

# %%
X_train.shape
# Out:
# (4057, 102688)

# %%
X_test.shape
# Out:
# (1739, 102688)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred = classifier.predict(X_test)

# %%
true_pos = (y_pred == 1) & (y_test == 1)
true_neg = (y_pred == 0) & (y_test == 0)
false_pos = (y_pred == 1) & (y_test == 0)
false_neg = (y_pred == 0) & (y_test == 1)
correct = true_neg.sum() + true_pos.sum()
print('The nr of documents classified correctly: ', correct)
incorrect = len(y_pred) - correct
print('The nr of documents classified incorrectly: ', incorrect)
# Out:
# The nr of documents classified correctly:  1659
# The nr of documents classified incorrectly:  80

# %%
accuracy = correct / len(y_test)
print('The testing accuracy is: {:.2%}'.format(accuracy))
# Out:
# The testing accuracy is: 95.40%

# %%
classifier.score(X_test,y_test)
# Out:
# 0.9539965497412306

# %%
# recall_score = true_pos.sum() / (true_pos.sum() + false_neg.sum())
# precision_score = true_pos.sum() / (true_pos.sum() + false_pos.sum())
# f1_score = 2 * ((precision_score*recall_score)/(precision_score+recall_score))
print('The recall score is: ', recall_score(y_test,y_pred))
print('The precision score is: ', precision_score(y_test,y_pred))
print('The F-Score is: ', f1_score(y_test,y_pred))
# Out:
# The recall score is:  0.8646209386281588
# The precision score is:  0.9896694214876033
# The F-Score is:  0.9229287090558767

# %% [markdown]
# ## Test the classifier with an example for fun

# %%
example = ['get viagra for free now!',
           'need a morgage? Reply to arrange a call with a specialist and get a quote',
           'Could you please help me with the project for tomorrow?',
          'Hello Jonathan, how about a gamme of golf tomorrow?',
          'Ski jumping is a winter sport in which competitors aim to achieve the farthest jump after sliding down on their skis from a specially designed curved ramp. Along with jump length, competitor\'s aerial style and other factors also affect the final score.Ski jumping was first contested in Norway in the late 19th century, and later spread through Europe and North America in the early 20th century. Along with cross-country skiing, it constitutes the traditional group of Nordic skiing disciplines.[1]']

# %%
doc_term_matrix = vectorize.transform(example)

# %%
classifier.predict(doc_term_matrix)
# Out:
# array([1, 1, 0, 0, 0])
